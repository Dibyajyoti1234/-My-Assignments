# %%
# Q-1
# probability density function performs on continous random variablee and lies between 0 to 1 and

# %%
# Q-2
# i)normal distribution ii)bernouli distribution iii)uniform distribution iv)poision distribution v)longnormal distribution vi)binomial distribution

# %%
# Q-3
# std(),mean()

# %%
# Q-4
# . Every experiment outcome is binary ii. This experiment performs for n times e.g :- tossing coin 10 times rolling a dice 3 times

# %%
# Q-5
import numpy as np
import matplotlib.pyplot as plt

n, p = 1000, 0.4  
s = np.random.binomial(n, p, 1000)

plt.hist(s)
plt.show()

# %%
# Q-6
from scipy.stats import poisson

def poisson_cdf(mean, point):
    return poisson.cdf(point, mean)

# %%
# Q-7
 # in binomial distribution the outcomes are boolean valued outcome

# %%
# Q-8
#
